# %% [markdown]
# ## Import Library

# %%
import math
import random as rd
import numpy as np

# %% [markdown]
# ## Nilai Fitness

# %%
def nilaiFitness(kombinasi):
    fitness = 0
    for i in range(1,len(kombinasi)):
        fitness = fitness + math.sqrt((math.pow((node[kombinasi[i]][0] - node[kombinasi[i-1]][0]),2))+math.pow((node[kombinasi[i-1]][1] - node[kombinasi[i]][1]),2))
    return -fitness

# %% [markdown]
# ## Seleksi Parent

# %%
def tournamentParent(populasi, panjangTournament):
    idxSample = np.arange(len(populasi))
    np.random.shuffle(idxSample)
    idxSample = idxSample[0:panjangTournament]
    fitnesses = [(nilaiFitness(pop[idxSample[i]])) for i in range(panjangTournament)]
    mergedArray = [(idxSample[i], fitnesses[i]) for i in range(panjangTournament)]
    mergedArray = sorted(mergedArray,key = lambda a : a[1], reverse = True)
    return mergedArray[0][0], mergedArray[1][0]

# %% [markdown]
# ## Generate Kromosom

# %%
def generateKromosom(jumlahPopulasi, panjangKromosom):
    populasi = []
    tmpStartEndNode = np.array([0])
    for i in range(jumlahPopulasi):
        kromosom = []
        kromosom = np.arange(1,panjangKromosom)
        np.random.shuffle(kromosom)
        kromosom = np.concatenate((tmpStartEndNode,kromosom), axis = 0)
        kromosom = np.concatenate((kromosom,tmpStartEndNode), axis = 0)
        populasi.append(list(kromosom))
    return populasi

# %% [markdown]
# ## Crossover

# %%
def crossover(kromosom1, kromosom2, pC):
    prob = np.random.random()
    point = np.random.randint(1,len(kromosom1)-1)
    tmpKromosom1 = []
    tmpKromosom2 = []
    cekKromosom1 = []
    cekKromosom2 = []
    if(prob <= pC):
        tmpKromosom1 = kromosom1[:point]
        tmpKromosom2 = kromosom2[:point]
        cekKromosom1 = kromosom1[point:]
        cekKromosom2 = kromosom2[point:]
        for i in range(point, len(kromosom2)):
            if(kromosom2[i] in tmpKromosom1):
                for j in range(len(kromosom1)):
                    if((kromosom1[j] not in tmpKromosom1) and (kromosom1[j] not in cekKromosom2)):
                        tmpKromosom1 = tmpKromosom1 + [kromosom1[j]]
                        break
                        
            else:
                tmpKromosom1 = tmpKromosom1 + [kromosom2[i]]
        for i in range(point, len(kromosom1)):
            if(kromosom1[i] in tmpKromosom2):
                for j in range(len(kromosom2)):
                    if((kromosom2[j] not in tmpKromosom2) and (kromosom2[j] not in cekKromosom1)):
                        tmpKromosom2 = tmpKromosom2 + [kromosom2[j]]
                        break
            else:
                tmpKromosom2 = tmpKromosom2 + [kromosom1[i]]
        
        tmpKromosom1 = tmpKromosom1 + kromosom1[len(kromosom1)-1:len(kromosom1)]
        tmpKromosom2 = tmpKromosom2 + kromosom2[len(kromosom2)-1:len(kromosom2)]
    else:
        tmpKromosom1 = kromosom1
        tmpKromosom2 = kromosom2
    return tmpKromosom1, tmpKromosom2

# %% [markdown]
# ## Mutasi

# %%
def mutasi(kromosom, pM):
    for i in range(1,len(kromosom)-1):
        tmp = 0
        prob = np.random.random()
        if(prob <= pM):
            while(tmp == 0):
                tmp = np.random.randint(1,len(kromosom)-2)
            for j in range(1, len(kromosom)-1):
                if(tmp == kromosom[j]):
                    kromosom[j] = kromosom[i]
                    kromosom[i] = tmp
                    break
    return kromosom

# %% [markdown]
# ## Pergantian Generasi (Steady State : Fitness-Based Selection)

# %%
def steadyState(jumlahGeneration ,populasi, jumlahPopulasi, panjangTournament):
    for j in range(jumlahGeneration):
        gabungan = []
        child = []
        fitnesses = []
#         print(populasi)
        for i in range(round(len(populasi)/2)):
            idxParent1, idxParent2 = tournamentParent(populasi, panjangTournament)
            anak1 = populasi[idxParent1][:]
            anak2 = populasi[idxParent2][:]
            
            #Crossover
            anak1,anak2 = crossover(anak1,anak2,pC)
            
            #Mutasi
            anak1 = mutasi(anak1,pM)
            anak2 = mutasi(anak2,pM)
            
            child.append(anak1)
            child.append(anak2)
            
        gabungan = populasi + child
        for i in range(len(gabungan)):
            fitnesses.append(nilaiFitness(gabungan[i]))
        mergedArray = [(gabungan[i], fitnesses[i]) for i in range(len(gabungan))]
        mergedArray = sorted(mergedArray, key = lambda a : a[1], reverse = True)
        pop = []
        tmp = []
        t = 0
        jumlah = 0
        
#         print(mergedArray)
        for i in range(len(gabungan)):
            if(i >= 1):
                nilai = nilaiFitness(gabungan[i])
                if(nilai == mergedArray[jumlah-1][1]):
                    tmp.append(mergedArray[i][0])
                    t += 1
                else:
                    pop.append(mergedArray[i][0])
                    jumlah+=1
            else:
                pop.append(mergedArray[i][0])
                jumlah+=1
            if(jumlah == jumlahPopulasi):
                break
        
        z = 0
#         print(len(populasi))
        while(jumlah < jumlahPopulasi):
            pop.append(tmp[z])
            z+=1
            jumlah+=1
        populasi = []
        populasi = pop
#         print(pop)
#         print(len(pop))
        
#         nilai = -nilaiFitness(populasi[0])
#         print()
#         print(nilai)
        
    return populasi

# %% [markdown]
# ## Inisialisasi Variable

# %%
node = [[82,76],
        [96,44],
        [50,5],
        [49,8],
        [13,7],
        [29,89],
        [58,30],
        [84,39],
        [14,24],
        [2,39],
        [3,82],
        [5,10],
        [98,52],
        [84,25],
        [61,59],
        [1,65]]

jumlahGenerasi = 100
jumlahIndividu = 50
panjangTournament = round(jumlahIndividu/2)
pC = 0.7
pM = 0.1

# %%
def steadyState(jumlahGeneration, populasi, jumlahPopulasi, panjangTournament):
    for j in range(jumlahGeneration):
        gabungan = []
        child = []
        fitnesses = []

        for i in range(round(len(populasi) / 2)):
            idxParent1, idxParent2 = tournamentParent(populasi, panjangTournament)
            anak1 = populasi[idxParent1][:]
            anak2 = populasi[idxParent2][:]

            # Crossover
            anak1, anak2 = crossover(anak1, anak2, pC)

            # Mutasi
            anak1 = mutasi(anak1, pM)
            anak2 = mutasi(anak2, pM)

            child.append(anak1)
            child.append(anak2)

        gabungan = populasi + child
        for i in range(len(gabungan)):
            fitnesses.append(nilaiFitness(gabungan[i]))
        mergedArray = [(gabungan[i], fitnesses[i]) for i in range(len(gabungan))]
        mergedArray = sorted(mergedArray, key=lambda a: a[1], reverse=True)
        pop = []
        tmp = []
        t = 0
        jumlah = 0

        for i in range(len(gabungan)):
            if (i >= 1):
                nilai = nilaiFitness(gabungan[i])
                if (nilai == mergedArray[jumlah - 1][1]):
                    tmp.append(mergedArray[i][0])
                    t += 1
                else:
                    pop.append(mergedArray[i][0])
                    jumlah += 1
            else:
                pop.append(mergedArray[i][0])
                jumlah += 1
            if (jumlah == jumlahPopulasi):
                break

        z = 0
        while (jumlah < jumlahPopulasi):
            pop.append(tmp[z])
            z += 1
            jumlah += 1
        populasi = pop

        # Print progress for each generation
        print(f"Generasi ke- {j + 1}")
        best_route = pop[0]
        best_cost = -nilaiFitness(best_route)
        print("Rute terbaik : " + str(best_route))
        print("Cost (jarak) : " + str(best_cost))
        print("----------------------------------")

    return populasi


# ... (rest of the code remains unchanged)

# %% [markdown]
# ## Main Program

# %%
pop = generateKromosom(jumlahIndividu,16)
pop = list(pop)
pop = steadyState(jumlahGenerasi, pop, jumlahIndividu, panjangTournament)
print("Generasi ke- "+str(jumlahGenerasi))
print("Rute terbaik : "+str(pop[0]))
print("Cost (jarak) : "+str(-nilaiFitness(pop[0])))
# Out:
# Generasi ke- 1
# Rute terbaik : [0, 14, 7, 13, 15, 9, 10, 5, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 665.3896288496564
# ----------------------------------
# Generasi ke- 2
# Rute terbaik : [0, 14, 7, 13, 15, 9, 10, 5, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 665.3896288496564
# ----------------------------------
# Generasi ke- 3
# Rute terbaik : [0, 14, 7, 13, 15, 9, 10, 5, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 665.3896288496564
# ----------------------------------
# Generasi ke- 4
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 628.7496354079794
# ----------------------------------
# Generasi ke- 5
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 628.7496354079794
# ----------------------------------
# Generasi ke- 6
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 628.7496354079794
# ----------------------------------
# Generasi ke- 7
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 11, 1, 12, 3, 4, 2, 6, 0]
# Cost (jarak) : 628.7496354079794
# ----------------------------------
# Generasi ke- 8
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 11, 1, 12, 2, 4, 3, 6, 0]
# Cost (jarak) : 627.5935169793414
# ----------------------------------
# Generasi ke- 9
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 2, 1, 12, 3, 4, 11, 6, 0]
# Cost (jarak) : 617.8651215330425
# ----------------------------------
# Generasi ke- 10
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 2, 1, 12, 3, 4, 11, 6, 0]
# Cost (jarak) : 617.8651215330425
# ----------------------------------
# Generasi ke- 11
# Rute terbaik : [0, 14, 7, 13, 15, 5, 10, 9, 8, 2, 1, 12, 3, 4, 11, 6, 0]
# Cost (jarak) : 617.8651215330425
# ----------------------------------
# Generasi ke- 12
# Rute terbaik : [0, 14, 7, 11, 8, 9, 10, 5, 15, 13, 1, 12, 2, 3, 4, 6, 0]
# Cost (jarak) : 615.951768412819
# ----------------------------------
# Generasi ke- 13
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 6, 3, 2, 7, 0]
# Cost (jarak) : 545.9456932939936
# ----------------------------------
# Generasi ke- 14
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 6, 3, 2, 7, 0]
# Cost (jarak) : 545.9456932939936
# ----------------------------------
# Generasi ke- 15
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 6, 3, 2, 7, 0]
# Cost (jarak) : 545.9456932939936
# ----------------------------------
# Generasi ke- 16
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 6, 3, 2, 7, 0]
# Cost (jarak) : 545.9456932939936
# ----------------------------------
# Generasi ke- 17
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 6, 3, 2, 7, 0]
# Cost (jarak) : 545.9456932939936
# ----------------------------------
# Generasi ke- 18
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 6, 3, 2, 7, 0]
# Cost (jarak) : 545.9456932939936
# ----------------------------------
# Generasi ke- 19
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 7, 1, 12, 2, 3, 13, 6, 0]
# Cost (jarak) : 544.8334655414575
# ----------------------------------
# Generasi ke- 20
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 7, 1, 12, 2, 3, 13, 6, 0]
# Cost (jarak) : 544.8334655414575
# ----------------------------------
# Generasi ke- 21
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 7, 1, 12, 2, 3, 13, 6, 0]
# Cost (jarak) : 544.8334655414575
# ----------------------------------
# Generasi ke- 22
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 535.3807887218393
# ----------------------------------
# Generasi ke- 23
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 535.3807887218393
# ----------------------------------
# Generasi ke- 24
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 535.3807887218393
# ----------------------------------
# Generasi ke- 25
# Rute terbaik : [0, 14, 4, 11, 15, 5, 10, 9, 8, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 535.3807887218393
# ----------------------------------
# Generasi ke- 26
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 1, 12, 7, 2, 3, 13, 0]
# Cost (jarak) : 524.9290140982099
# ----------------------------------
# Generasi ke- 27
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 13, 1, 12, 7, 2, 3, 6, 0]
# Cost (jarak) : 517.8569712360721
# ----------------------------------
# Generasi ke- 28
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 13, 1, 12, 7, 2, 3, 6, 0]
# Cost (jarak) : 517.8569712360721
# ----------------------------------
# Generasi ke- 29
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 13, 1, 12, 7, 2, 3, 6, 0]
# Cost (jarak) : 517.8569712360721
# ----------------------------------
# Generasi ke- 30
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 13, 1, 12, 7, 2, 3, 6, 0]
# Cost (jarak) : 517.8569712360721
# ----------------------------------
# Generasi ke- 31
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 501.44913702244526
# ----------------------------------
# Generasi ke- 32
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 501.44913702244526
# ----------------------------------
# Generasi ke- 33
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 13, 1, 12, 7, 3, 2, 6, 0]
# Cost (jarak) : 501.44913702244526
# ----------------------------------
# Generasi ke- 34
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 35
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 36
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 37
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 38
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 39
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 40
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 41
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 42
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 43
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 44
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 45
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 46
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 47
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 48
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 49
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 5, 15, 6, 2, 3, 7, 12, 1, 13, 0]
# Cost (jarak) : 492.9143800595055
# ----------------------------------
# Generasi ke- 50
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 7, 1, 12, 13, 2, 3, 6, 0]
# Cost (jarak) : 483.442503470167
# ----------------------------------
# Generasi ke- 51
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 7, 1, 12, 13, 2, 3, 6, 0]
# Cost (jarak) : 483.442503470167
# ----------------------------------
# Generasi ke- 52
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 7, 13, 12, 1, 0]
# Cost (jarak) : 473.6920414395967
# ----------------------------------
# Generasi ke- 53
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 7, 13, 12, 1, 0]
# Cost (jarak) : 473.6920414395967
# ----------------------------------
# Generasi ke- 54
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 7, 13, 12, 1, 0]
# Cost (jarak) : 473.6920414395967
# ----------------------------------
# Generasi ke- 55
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 7, 13, 12, 1, 0]
# Cost (jarak) : 473.6920414395967
# ----------------------------------
# Generasi ke- 56
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 12, 1, 7, 0]
# Cost (jarak) : 461.9666748510146
# ----------------------------------
# Generasi ke- 57
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 12, 1, 7, 0]
# Cost (jarak) : 461.9666748510146
# ----------------------------------
# Generasi ke- 58
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 12, 1, 7, 0]
# Cost (jarak) : 461.9666748510146
# ----------------------------------
# Generasi ke- 59
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 12, 1, 7, 0]
# Cost (jarak) : 461.9666748510146
# ----------------------------------
# Generasi ke- 60
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 12, 1, 7, 0]
# Cost (jarak) : 461.9666748510146
# ----------------------------------
# Generasi ke- 61
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 12, 1, 7, 0]
# Cost (jarak) : 461.9666748510146
# ----------------------------------
# Generasi ke- 62
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 454.53867596909197
# ----------------------------------
# Generasi ke- 63
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 454.53867596909197
# ----------------------------------
# Generasi ke- 64
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 454.53867596909197
# ----------------------------------
# Generasi ke- 65
# Rute terbaik : [0, 14, 4, 11, 8, 9, 5, 10, 15, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 454.53867596909197
# ----------------------------------
# Generasi ke- 66
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 449.5323191399145
# ----------------------------------
# Generasi ke- 67
# Rute terbaik : [0, 14, 4, 11, 8, 9, 10, 15, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 449.5323191399145
# ----------------------------------
# Generasi ke- 68
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 7, 13, 1, 12, 0]
# Cost (jarak) : 427.7152323575415
# ----------------------------------
# Generasi ke- 69
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 70
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 71
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 72
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 73
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 74
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 75
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 76
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 77
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 78
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 79
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 80
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 81
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 82
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 83
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 84
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 12, 1, 0]
# Cost (jarak) : 422.5875626737177
# ----------------------------------
# Generasi ke- 85
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 86
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 87
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 88
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 89
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 90
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 91
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 92
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 93
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 94
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 95
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 2, 3, 13, 7, 1, 12, 0]
# Cost (jarak) : 410.3985013097408
# ----------------------------------
# Generasi ke- 96
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 3, 2, 13, 7, 1, 12, 0]
# Cost (jarak) : 408.4554333908815
# ----------------------------------
# Generasi ke- 97
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 3, 2, 13, 7, 1, 12, 0]
# Cost (jarak) : 408.4554333908815
# ----------------------------------
# Generasi ke- 98
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 3, 2, 13, 7, 1, 12, 0]
# Cost (jarak) : 408.4554333908815
# ----------------------------------
# Generasi ke- 99
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 3, 2, 13, 7, 1, 12, 0]
# Cost (jarak) : 408.4554333908815
# ----------------------------------
# Generasi ke- 100
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 3, 2, 13, 7, 1, 12, 0]
# Cost (jarak) : 408.4554333908815
# ----------------------------------
# Generasi ke- 100
# Rute terbaik : [0, 14, 4, 11, 8, 9, 15, 10, 5, 6, 3, 2, 13, 7, 1, 12, 0]
# Cost (jarak) : 408.4554333908815
